# %% [markdown]
# ## Matplotlib :
# - It is plotting library for python programming language

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
# simple example

x = np.arange(0,10)
y = np.arange(11,21)

# %%
#plot using matplotlib

plt.scatter(x , y , c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
# saveing the figure
plt.savefig('plt.png')

# %%
y = x * x

# %%
# plot function

plt.plot(x , y, 'r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
plt.plot(x , y, '*--r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
# Create subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'c')

# %%
x = np.arange(1,11)
y = 3 * x + 5

plt.title('Matplotlib Demo')
plt.xlabel('X axis caption')
plt.ylabel('Y axis caption')
plt.plot(x,y)
plt.show()

# %%
#pie value
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve

x = np.arange(0, 4*np.pi , 0.1)
y = np.sin(x)
plt.title('Sine wave form')
plt.plot(x,y)

# %%
# subplot
# craete the x and y coordinates for sine, cos, tan cureves
x = np.arange(0, 5 *np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)

#setting subplots
plt.subplot(2,1,1)
plt.plot(x,y_sin,'r--')
plt.title('sine wave curve')
plt.subplot(2,1,2)
plt.plot(x,y_cos,'g--')
plt.title('Cos wave curve')
# Out:
# Text(0.5, 1.0, 'Cos wave curve')

# %% [markdown]
# ## Bar plot

# %%
x = [2,8,10]
y = [11,16,9]

x2 = [3,9,11]
y2 = [6,15,7]

plt.bar(x , y )
plt.bar(x2,y2,color='g')
plt.title('Bar Graph ')
plt.xlabel('X axis ')
plt.ylabel('Y axis ')
plt.show()

# %% [markdown]
# ## Histograms

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)
plt.title('Histograms')
plt.show()

# %% [markdown]
# ## Box plot using Matplotlib

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]

#Rectangled box plot
plt.boxplot(data,vert=True,patch_artist=True)
plt.show()

# %%
plt.boxplot(data,vert=False,patch_artist=False) #verticaltrue and patch artist -> false
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# Data 
labels = 'Python', 'C++','Java','Ruby'
sizes = [215,130,245,210]
colors = ['gold','green','lightcoral','lightskyblue']
explode = (0.2,0,0,0) # explode 1st slice

#plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%')
plt.axis('equal')
plt.show()
